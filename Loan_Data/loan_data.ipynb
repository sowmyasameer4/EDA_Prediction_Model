# %% [markdown]
# <a href="https://colab.research.google.com/github/sowmyasameer4/EDA_Prediction_Model/blob/main/Loan_Data/loan_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Loan Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Datasets/loan_data.csv")
df
# Out:
#        person_age person_gender person_education  person_income  \
# 0            22.0        female           Master        71948.0
# 1            21.0        female      High School        12282.0
# 2            25.0        female      High School        12438.0
# 3            23.0        female         Bachelor        79753.0
# 4            24.0          male           Master        66135.0
# ...           ...           ...              ...            ...
# 44995        27.0          male        Associate        47971.0
# 44996        37.0        female        Associate        65800.0
# 44997        33.0          male        Associate        56942.0
# 44998        29.0          male         Bachelor        33164.0
# 44999        24.0          male      High School        51609.0
#
#        person_emp_exp person_home_ownership  loan_amnt        loan_intent  \
# 0                   0                  RENT    35000.0           PERSONAL
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45000 entries, 0 to 44999
# Data columns (total 14 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   person_age                      45000 non-null  float64
#  1   person_gender                   45000 non-null  object
#  2   person_education                45000 non-null  object
#  3   person_income                   45000 non-null  float64
#  4   person_emp_exp                  45000 non-null  int64
#  5   person_home_ownership           45000 non-null  object
#  6   loan_amnt                       45000 non-null  float64
#  7   loan_intent                     45000 non-null  object
#  8   loan_int_rate                   45000 non-null  float64
#  9   loan_percent_income             45000 non-null  float64
#  10  cb_person_cred_hist_length      45000 non-null  float64
#  11  credit_score                    45000 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# person_age                        0
# person_gender                     0
# person_education                  0
# person_income                     0
# person_emp_exp                    0
# person_home_ownership             0
# loan_amnt                         0
# loan_intent                       0
# loan_int_rate                     0
# loan_percent_income               0
# cb_person_cred_hist_length        0
# credit_score                      0
# previous_loan_defaults_on_file    0
# loan_status                       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#          person_age  person_income  person_emp_exp     loan_amnt  \
# count  45000.000000   4.500000e+04    45000.000000  45000.000000
# mean      27.764178   8.031905e+04        5.410333   9583.157556
# std        6.045108   8.042250e+04        6.063532   6314.886691
# min       20.000000   8.000000e+03        0.000000    500.000000
# 25%       24.000000   4.720400e+04        1.000000   5000.000000
# 50%       26.000000   6.704800e+04        4.000000   8000.000000
# 75%       30.000000   9.578925e+04        8.000000  12237.250000
# max      144.000000   7.200766e+06      125.000000  35000.000000
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# count   45000.000000         45000.000000                45000.000000
# mean       11.006606             0.139725                    5.867489
# std         2.978808             0.087212                    3.879702
# min         5.420000             0.000000                    2.000000
# ...

# %%
df.hist(figsize=(15,15))
# Out:
# array([[<Axes: title={'center': 'person_age'}>,
#         <Axes: title={'center': 'person_income'}>,
#         <Axes: title={'center': 'person_emp_exp'}>],
#        [<Axes: title={'center': 'loan_amnt'}>,
#         <Axes: title={'center': 'loan_int_rate'}>,
#         <Axes: title={'center': 'loan_percent_income'}>],
#        [<Axes: title={'center': 'cb_person_cred_hist_length'}>,
#         <Axes: title={'center': 'credit_score'}>,
#         <Axes: title={'center': 'loan_status'}>]], dtype=object)

# %% [markdown]
# Visualisation

# %%
df["loan_amnt"].hist()
# Out:
# <Axes: >

# %%
df.hist(color="black", edgecolor="b",figsize=(15,10))
# Out:
# array([[<Axes: title={'center': 'person_age'}>,
#         <Axes: title={'center': 'person_income'}>,
#         <Axes: title={'center': 'person_emp_exp'}>],
#        [<Axes: title={'center': 'loan_amnt'}>,
#         <Axes: title={'center': 'loan_int_rate'}>,
#         <Axes: title={'center': 'loan_percent_income'}>],
#        [<Axes: title={'center': 'cb_person_cred_hist_length'}>,
#         <Axes: title={'center': 'credit_score'}>,
#         <Axes: title={'center': 'loan_status'}>]], dtype=object)

# %%
sns.histplot(df["loan_int_rate"],bins=10,color="gray",edgecolor="pink",kde=True)
plt.figure(figsize=(30,8))

# %%
df["person_gender"].hist(color="k")
# Out:
# <Axes: >

# %%
df["person_education"].hist(color='purple')
# Out:
# <Axes: >

# %%
df["loan_amnt"].hist(color="orange")
# Out:
# <Axes: >

# %% [markdown]
# ### Correlation Analysis

# %%
dummies=pd.get_dummies(df["person_gender"]).astype(int)
dummies
# Out:
#        female  male
# 0           1     0
# 1           1     0
# 2           1     0
# 3           1     0
# 4           0     1
# ...       ...   ...
# 44995       0     1
# 44996       1     0
# 44997       0     1
# 44998       0     1
# 44999       0     1
#
# [45000 rows x 2 columns]

# %%
df=pd.concat([df,dummies],axis="columns")

# %%
df
# Out:
#        person_age person_gender person_education  person_income  \
# 0            22.0        female           Master        71948.0
# 1            21.0        female      High School        12282.0
# 2            25.0        female      High School        12438.0
# 3            23.0        female         Bachelor        79753.0
# 4            24.0          male           Master        66135.0
# ...           ...           ...              ...            ...
# 44995        27.0          male        Associate        47971.0
# 44996        37.0        female        Associate        65800.0
# 44997        33.0          male        Associate        56942.0
# 44998        29.0          male         Bachelor        33164.0
# 44999        24.0          male      High School        51609.0
#
#        person_emp_exp person_home_ownership  loan_amnt        loan_intent  \
# 0                   0                  RENT    35000.0           PERSONAL
# ...

# %%
df.drop(["person_gender"],axis="columns",inplace=True)
df
# Out:
#        person_age person_education  person_income  person_emp_exp  \
# 0            22.0           Master        71948.0               0
# 1            21.0      High School        12282.0               0
# 2            25.0      High School        12438.0               3
# 3            23.0         Bachelor        79753.0               0
# 4            24.0           Master        66135.0               1
# ...           ...              ...            ...             ...
# 44995        27.0        Associate        47971.0               6
# 44996        37.0        Associate        65800.0              17
# 44997        33.0        Associate        56942.0               7
# 44998        29.0         Bachelor        33164.0               4
# 44999        24.0      High School        51609.0               1
#
#       person_home_ownership  loan_amnt        loan_intent  loan_int_rate  \
# 0                      RENT    35000.0           PERSONAL          16.02
# ...

# %%
df['person_education'].count()
# Out:
# np.int64(45000)

# %%
df['person_education'].unique()
# Out:
# array(['Master', 'High School', 'Bachelor', 'Associate', 'Doctorate'],
#       dtype=object)

# %%
df["person_education"].replace(['High School','Associate','Bachelor','Master','Doctorate'],[1,2,3,4,5],inplace=True)
# Out:
# /tmp/ipykernel_256/3497541628.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["person_education"].replace(['High School','Associate','Bachelor','Master','Doctorate'],[1,2,3,4,5],inplace=True)
# /tmp/ipykernel_256/3497541628.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# ...

# %%
df
# Out:
#        person_age  person_education  person_income  person_emp_exp  \
# 0            22.0                 4        71948.0               0
# 1            21.0                 1        12282.0               0
# 2            25.0                 1        12438.0               3
# 3            23.0                 3        79753.0               0
# 4            24.0                 4        66135.0               1
# ...           ...               ...            ...             ...
# 44995        27.0                 2        47971.0               6
# 44996        37.0                 2        65800.0              17
# 44997        33.0                 2        56942.0               7
# 44998        29.0                 3        33164.0               4
# 44999        24.0                 1        51609.0               1
#
#       person_home_ownership  loan_amnt        loan_intent  loan_int_rate  \
# 0                      RENT    35000.0           PERSONAL          16.02
# ...

# %%
df["person_home_ownership"].unique()
# Out:
# array(['RENT', 'OWN', 'MORTGAGE', 'OTHER'], dtype=object)

# %%
df["person_home_ownership"].replace(['RENT', 'MORTGAGE', 'OWN', 'OTHER'],[1,2,3,4], inplace=True)
df
# Out:
# /tmp/ipykernel_256/1770029423.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["person_home_ownership"].replace(['RENT', 'MORTGAGE', 'OWN', 'OTHER'],[1,2,3,4], inplace=True)
# /tmp/ipykernel_256/1770029423.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# ...

# %%
df
# Out:
#        person_age  person_education  person_income  person_emp_exp  \
# 0            22.0                 4        71948.0               0
# 1            21.0                 1        12282.0               0
# 2            25.0                 1        12438.0               3
# 3            23.0                 3        79753.0               0
# 4            24.0                 4        66135.0               1
# ...           ...               ...            ...             ...
# 44995        27.0                 2        47971.0               6
# 44996        37.0                 2        65800.0              17
# 44997        33.0                 2        56942.0               7
# 44998        29.0                 3        33164.0               4
# 44999        24.0                 1        51609.0               1
#
#        person_home_ownership  loan_amnt        loan_intent  loan_int_rate  \
# 0                          1    35000.0           PERSONAL          16.02
# ...

# %%
df["loan_intent"].unique()
# Out:
# array(['PERSONAL', 'EDUCATION', 'MEDICAL', 'VENTURE', 'HOMEIMPROVEMENT',
#        'DEBTCONSOLIDATION'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder #use labelencoder when the data is nominal
                                               #use replace when the data is ordinal
                                               #to create separate columns,use dummies(one-hot encoding) when there is only two values in a column

labelencoder=LabelEncoder()

df["loan_intent"]=labelencoder.fit_transform(df["loan_intent"])

df["previous_loan_defaults_on_file"]=labelencoder.fit_transform(df["previous_loan_defaults_on_file"])

df
# Out:
#        person_age  person_education  person_income  person_emp_exp  \
# 0            22.0                 4        71948.0               0
# 1            21.0                 1        12282.0               0
# 2            25.0                 1        12438.0               3
# 3            23.0                 3        79753.0               0
# 4            24.0                 4        66135.0               1
# ...           ...               ...            ...             ...
# 44995        27.0                 2        47971.0               6
# 44996        37.0                 2        65800.0              17
# 44997        33.0                 2        56942.0               7
# 44998        29.0                 3        33164.0               4
# 44999        24.0                 1        51609.0               1
#
#        person_home_ownership  loan_amnt  loan_intent  loan_int_rate  \
# 0                          1    35000.0            4          16.02
# ...

# %%
df
# Out:
#        person_age  person_education  person_income  person_emp_exp  \
# 0            22.0                 4        71948.0               0
# 1            21.0                 1        12282.0               0
# 2            25.0                 1        12438.0               3
# 3            23.0                 3        79753.0               0
# 4            24.0                 4        66135.0               1
# ...           ...               ...            ...             ...
# 44995        27.0                 2        47971.0               6
# 44996        37.0                 2        65800.0              17
# 44997        33.0                 2        56942.0               7
# 44998        29.0                 3        33164.0               4
# 44999        24.0                 1        51609.0               1
#
#        person_home_ownership  loan_amnt  loan_intent  loan_int_rate  \
# 0                          1    35000.0            4          16.02
# ...

# %%
df.describe()
# Out:
#          person_age  person_education  person_income  person_emp_exp  \
# count  45000.000000      45000.000000   4.500000e+04    45000.000000
# mean      27.764178          2.383333   8.031905e+04        5.410333
# std        6.045108          1.077741   8.042250e+04        6.063532
# min       20.000000          1.000000   8.000000e+03        0.000000
# 25%       24.000000          1.000000   4.720400e+04        1.000000
# 50%       26.000000          2.000000   6.704800e+04        4.000000
# 75%       30.000000          3.000000   9.578925e+04        8.000000
# max      144.000000          5.000000   7.200766e+06      125.000000
#
#        person_home_ownership     loan_amnt   loan_intent  loan_int_rate  \
# count           45000.000000  45000.000000  45000.000000   45000.000000
# mean                1.549822   9583.157556      2.525911      11.006606
# std                 0.627919   6314.886691      1.728305       2.978808
# ...

# %%
corr_matrix=df.corr()

sns.heatmap(corr_matrix,annot=True,fmt='0.01f',cmap='coolwarm')
plt.title('correlation matrix')
plt.show()

# %%
price_corr = df.corr()['loan_status']

price_corr = price_corr.drop('loan_status')

sns.heatmap(price_corr.to_frame(), annot=True, fmt='.2f', cmap='coolwarm',
            cbar=True, annot_kws={'size': 10})  # to_frame() converts Series to DataFrame for heatmap
plt.title('Correlation between loan_status and Other Features')
plt.show()

# %%
df.drop(["male","female","credit_score","cb_person_cred_hist_length","loan_intent","person_emp_exp","person_education","person_age","loan_amnt","person_income"],axis=1,inplace=True)

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
def remove_outliers_iqr(df,exclude_column):
    for col in df.columns:
        # Skip the specified column
        if col == exclude_column:
            continue
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        # Filter the DataFrame to remove rows with outliers in each column
        df = df[(df[col] >= lower_bound) & (df[col] <= upper_bound)]
    return df

# Specify the column to exclude
df_cleaned = remove_outliers_iqr(df, exclude_column='loan_status')
df=df_cleaned

# %%
df
# Out:
#        person_home_ownership  loan_int_rate  loan_percent_income  \
# 1                          3          11.14                 0.08
# 5                          3           7.14                 0.19
# 6                          1          12.42                 0.37
# 7                          1          11.11                 0.37
# 8                          1           8.90                 0.35
# ...                      ...            ...                  ...
# 44995                      1          15.66                 0.31
# 44996                      1          14.07                 0.14
# 44997                      1          10.02                 0.05
# 44998                      1          13.23                 0.36
# 44999                      1          17.05                 0.13
#
#        previous_loan_defaults_on_file  loan_status
# 1                                   1            0
# 5                                   0            1
# ...

# %% [markdown]
# Data Scaling

# %%
from sklearn.preprocessing import MinMaxScaler

features = ["previous_loan_defaults_on_file","loan_percent_income","loan_int_rate","person_home_ownership"]

scaler = MinMaxScaler()

scaled_data = scaler.fit_transform(df[features])

scaled_df = pd.DataFrame(scaled_data, columns=features, index=df.index)

# %% [markdown]
# Predicting Scaled Data

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

X=df[["previous_loan_defaults_on_file","loan_percent_income","loan_int_rate","person_home_ownership"]]
Y=df['loan_status']

X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.25,random_state=42)

model= LogisticRegression()
model.fit(X_train,Y_train)

Y_pred=model.predict(X_test)
model.score(X_test,Y_test)
# Out:
# 0.8819627442071786
