# %% [markdown]
# <a href="https://colab.research.google.com/github/sowmyasameer4/EDA_Prediction_Model/blob/main/Diamond/Diamond.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## diamond

# %%
import pandas as pd
data=pd.read_csv("/content/diamonds.csv")
data
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 49995   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 49996   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 49997   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 49998   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 49999   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [50000 rows x 10 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    50000 non-null  float64
#  1   cut      50000 non-null  object
#  2   color    50000 non-null  object
#  3   clarity  50000 non-null  object
#  4   depth    50000 non-null  float64
#  5   table    50000 non-null  float64
#  6   price    50000 non-null  int64
#  7   x        50000 non-null  float64
#  8   y        50000 non-null  float64
#  9   z        50000 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 3.8+ MB

# %%
data.isnull().sum()
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# x          0
# y          0
# z          0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# np.int64(126)

# %%
data.shape
# Out:
# (50000, 10)

# %%
data.drop_duplicates(inplace=True)

# %%
data.shape
# Out:
# (49874, 10)

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(data["price"])
plt.show()

# %%
print(data['cut'].unique())
# Out:
# ['Ideal' 'Premium' 'Good' 'Very Good' 'Fair']

# %%
data["cut"].replace(["Fair","Good","Very Good","Premium","Ideal"],[1,2,3,4,5],inplace=True)
# Out:
# /tmp/ipython-input-2742423181.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data["cut"].replace(["Fair","Good","Very Good","Premium","Ideal"],[1,2,3,4,5],inplace=True)
# /tmp/ipython-input-2742423181.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# ...

# %%
data
# Out:
#        carat  cut color clarity  depth  table  price     x     y     z
# 0       0.23    5     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    4     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23    2     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    4     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31    2     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...  ...   ...     ...    ...    ...    ...   ...   ...   ...
# 49995   0.72    5     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 49996   0.72    2     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 49997   0.70    3     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 49998   0.86    4     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 49999   0.75    5     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [49874 rows x 10 columns]

# %%
print(data['color'].unique())
# Out:
# ['E' 'I' 'J' 'H' 'F' 'G' 'D']

# %%
data["color"].replace(["J","I","H","G","F","E","D"],[1,2,3,4,5,6,7],inplace=True)
# Out:
# /tmp/ipython-input-2539280264.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data["color"].replace(["J","I","H","G","F","E","D"],[1,2,3,4,5,6,7],inplace=True)
# /tmp/ipython-input-2539280264.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# ...

# %%
data
# Out:
#        carat  cut  color clarity  depth  table  price     x     y     z
# 0       0.23    5      6     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    4      6     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23    2      6     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    4      2     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31    2      1     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...  ...    ...     ...    ...    ...    ...   ...   ...   ...
# 49995   0.72    5      7     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 49996   0.72    2      7     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 49997   0.70    3      7     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 49998   0.86    4      3     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 49999   0.75    5      7     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [49874 rows x 10 columns]

# %%
print(data["clarity"].unique())
# Out:
# ['SI2' 'SI1' 'VS1' 'VS2' 'VVS2' 'VVS1' 'I1' 'IF']

# %%
data["clarity"].replace(["I1","SI2","SI1","VS2","VS1","VVS2","VVS1","IF"],[1,2,3,4,5,6,7,8],inplace=True)
# Out:
# /tmp/ipython-input-2033482641.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data["clarity"].replace(["I1","SI2","SI1","VS2","VS1","VVS2","VVS1","IF"],[1,2,3,4,5,6,7,8],inplace=True)
# /tmp/ipython-input-2033482641.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# ...

# %%
data
# Out:
#        carat  cut  color  clarity  depth  table  price     x     y     z
# 0       0.23    5      6        2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    4      6        3   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23    2      6        5   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    4      2        4   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31    2      1        2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...  ...    ...      ...    ...    ...    ...   ...   ...   ...
# 49995   0.72    5      7        3   60.8   57.0   2757  5.75  5.76  3.50
# 49996   0.72    2      7        3   63.1   55.0   2757  5.69  5.75  3.61
# 49997   0.70    3      7        3   62.8   60.0   2757  5.66  5.68  3.56
# 49998   0.86    4      3        2   61.0   58.0   2757  6.15  6.12  3.74
# 49999   0.75    5      7        2   62.2   55.0   2757  5.83  5.87  3.64
#
# [49874 rows x 10 columns]

# %%
import seaborn as sns

# %%
corr_matrix=data.corr()

sns.heatmap(corr_matrix,annot=True,fmt='0.01f', cmap='coolwarm')
plt.title('correlation matrix')
plt.show()

# %%
price_corr = data.corr()['price']

price_corr = price_corr.drop('price')

sns.heatmap(price_corr.to_frame(), annot=True, fmt='.2f', cmap='coolwarm',
            cbar=True, annot_kws={'size': 10})  # to_frame() converts Series to DataFrame for heatmap
plt.title('Correlation between price and Other Features')
plt.show()

# %%
# data.drop(["cut","depth","table"],axis=1,inplace=True) # These columns have already been dropped.

# %%
data.boxplot()
# Out:
# <Axes: >

# %%
# Function to remove outliers using the IQR method except for one column
def remove_outliers_iqr(data, exclude_column):
    for col in data.columns:
        # Skip the specified column
        if col == exclude_column:
            continue
        Q1 = data[col].quantile(0.25)
        Q3 = data[col].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        # Filter the DataFrame to remove rows with outliers in each column
        data = data[(data[col] >= lower_bound) & (data[col] <= upper_bound)]
    return data

# Specify the column to exclude
data_cleaned = remove_outliers_iqr(data, exclude_column='price')
data=data_cleaned

# %%
data.shape
# Out:
# (45207, 10)

# %%
data
# Out:
#        carat  cut  color  clarity  depth  table  price     x     y     z
# 0       0.23    5      6        2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    4      6        3   59.8   61.0    326  3.89  3.84  2.31
# 3       0.29    4      2        4   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31    2      1        2   63.3   58.0    335  4.34  4.35  2.75
# 5       0.24    3      1        6   62.8   57.0    336  3.94  3.96  2.48
# ...      ...  ...    ...      ...    ...    ...    ...   ...   ...   ...
# 49995   0.72    5      7        3   60.8   57.0   2757  5.75  5.76  3.50
# 49996   0.72    2      7        3   63.1   55.0   2757  5.69  5.75  3.61
# 49997   0.70    3      7        3   62.8   60.0   2757  5.66  5.68  3.56
# 49998   0.86    4      3        2   61.0   58.0   2757  6.15  6.12  3.74
# 49999   0.75    5      7        2   62.2   55.0   2757  5.83  5.87  3.64
#
# [45207 rows x 10 columns]

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler



# Select the features that you want to scale
features = ['carat', 'color', 'clarity','price']

# Create a MinMaxScaler object
scaler = MinMaxScaler()

# Fit the scaler to your data and transform it
scaled_data = scaler.fit_transform(data[features])

# Create a DataFrame from scaled_data with the correct column names
scaled_data = pd.DataFrame(scaled_data, columns=features)
